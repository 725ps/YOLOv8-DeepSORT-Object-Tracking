# %% [markdown]
# <a href="https://colab.research.google.com/github/725ps/YOLOv8-DeepSORT-Object-Tracking/blob/main/YOLOv8_45k_images_training_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Before Running the Script Please Make Sure you Select the Run Time as GPU

# %% [markdown]
# #**Import the Required Libraries**

# %%
from IPython.display import Image
import numpy as np

# %% [markdown]
# #**Clone the Github Repo**

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git
# Out:
# Cloning into 'YOLOv8-DeepSORT-Object-Tracking'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 403 (delta 21), reused 19 (delta 19), pack-reused 370 (from 1)
# Receiving objects: 100% (403/403), 77.99 MiB | 15.62 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ##Setting the Current Directory

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///content/YOLOv8-DeepSORT-Object-Tracking
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Install all the Dependencies

# %% [markdown]
# ##Moving to the Required Directory

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=1D7LX_RyVBBEZy66SXbyrLlRmBypv0Mo6&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1D7LX_RyVBBEZy66SXbyrLlRmBypv0Mo6&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/combined.zip
# 100% 3.66G/3.66G [01:04<00:00, 56.8MB/s]

# %% [markdown]
# ##Importing the Dataset from the RoboFlow

# %%
# !ls
# Out:
# combined.zip  __init__.py  predict.py  train.py  val.py

# %%
# !unzip 'combined.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: combined/valid/images/frame_5_384_jpg.rf.4ac8194382d17a7e95f645ba5e04d847.jpg
#   inflating: combined/valid/images/frame_5_386_jpg.rf.9757544de02d8bac9530a17ede907e1e.jpg
#   inflating: combined/valid/images/frame_5_388_jpg.rf.8ee71b7cf7514a5c9c6f4d521c49271b.jpg
#   inflating: combined/valid/images/frame_5_390_jpg.rf.6dee47da95ef2e70b4366956fdd35f93.jpg
#   inflating: combined/valid/images/frame_5_392_jpg.rf.2cacf198931e8a1561b0081103e80066.jpg
#   inflating: combined/valid/images/frame_5_394_jpg.rf.25bb7a8a39779f81adb07f42de366b15.jpg
#   inflating: combined/valid/images/frame_5_396_jpg.rf.b0b3bda35af949fdf1582b964da144be.jpg
#   inflating: combined/valid/images/frame_5_398_jpg.rf.458c150d3a5e5235d59c373bede2954d.jpg
#   inflating: combined/valid/images/frame_5_400_jpg.rf.896d8d52811575d5ccc00e3eceedb730.jpg
#   inflating: combined/valid/images/frame_5_402_jpg.rf.4ac010dc5d78e8281772b30e52f292da.jpg
# ...

# %%
# !ls
# Out:
# combined  combined.zip	__init__.py  predict.py  train.py  val.py

# %% [markdown]
# ##To implement the DeepSORT tracking, downloading the required files

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100% 43.1M/43.1M [00:00<00:00, 67.1MB/s]

# %% [markdown]
# ##Unzipping the DeepSORT Files

# %%
# !unzip 'deep_sort_pytorch.zip'
# Out:
# Archive:  deep_sort_pytorch.zip
#   inflating: deep_sort_pytorch/.gitignore
#    creating: deep_sort_pytorch/configs/
#   inflating: deep_sort_pytorch/configs/deep_sort.yaml
#    creating: deep_sort_pytorch/deep_sort/
#   inflating: deep_sort_pytorch/deep_sort/__init__.py
#    creating: deep_sort_pytorch/deep_sort/__pycache__/
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-38.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-38.pyc
#    creating: deep_sort_pytorch/deep_sort/deep/
#  extracting: deep_sort_pytorch/deep_sort/deep/__init__.py
#    creating: deep_sort_pytorch/deep_sort/deep/__pycache__/
# ...

# %% [markdown]
# #**Training the Custom Model**

# %%
HOME = '/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# %cd {HOME}

#!python train.py model=yolov8n.pt data="/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/combined/data.yaml" epochs=50 imgsz=640
# !python train.py model=yolov8l.pt data="/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/combined/data.yaml" epochs=50 imgsz=640 batch=16 patience=25 optimizer=SGD device=0 workers=8 pretrained=True name=person_detector_v1
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(self.amp):
#       50/50      14.4G     0.7343     0.3756      1.026         67        640:  14% 388/2836 [01:02<06:19,  6.45it/s]/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       50/50      14.4G     0.7339     0.3755      1.026         29        640:  14% 389/2836 [01:02<06:44,  6.05it/s]/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# ...

# %%
from google.colab import files
files.download('/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/person_detector_v1/weights/best.pt')
files.download('/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/person_detector_v1/weights/last.pt')

# %%
# !gdown "https://drive.google.com/uc?id=1wQXMEiq9txLsTnGFLXsUFbhlsMhoRPcA"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wQXMEiq9txLsTnGFLXsUFbhlsMhoRPcA
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/ps_test_1.mp4
# 100% 5.68M/5.68M [00:00<00:00, 18.0MB/s]

# %%
# !python predict.py model='/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/person_detector_v1/weights/best.pt' source='/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/ps_test_1.mp4'
# Out:
# [2025-04-16 03:10:03,216][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2025-04-16 03:10:03.526203: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-16 03:10:03.542413: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744773003.561093  141411 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train3/ps_test_1.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

# Compress the video using ffmpeg
os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Read and encode the compressed video
mp4 = open(compressed_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# Display the video using HTML
HTML(f"""
<video width=600 controls>
    <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width=600 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
